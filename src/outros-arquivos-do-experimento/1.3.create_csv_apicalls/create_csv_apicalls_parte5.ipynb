# %%
import uuid

# %%
import pandas as pd
import modin.pandas as mpd
import ray
import os


# ray.shutdown()
os.environ["MODIN_ENGINE"] = "ray"

runtime_env = {
    'env_vars': {
        "RAY_memory_monitor_refresh_ms": "100",
        "RAY_memory_usage_threshold": "0.85"
     }
}
ray.init(runtime_env=runtime_env)
# Out:
# 2024-04-12 18:28:40,591	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.10.12', ray_version='2.10.0', ray_commit='09abba26b5bf2707639bb637c208d062a47b46f6')

# %%
def is_valid_file(file_name, file_type):
    return file_name.endswith(file_type)

def is_permission_file(file_name):
    return is_valid_file(file_name, "-analysis-permissions.csv")

def is_apicall_file(file_name):
    return is_valid_file(file_name, "-analysis-apicalls.csv")

def is_opcode_file(file_name):
    return is_valid_file(file_name, "-analysis-opcodes.csv")

# %%
files_completo = sorted(os.scandir("3.PREPROCESSING-40k/"), key=lambda e: e.name)

# %%
files = files_completo[60_000:75_000]

# %%
count = 0

total_files = len(files)

# %%
output_csv = "csv/"
permission_df_list_tmp = []
permission_df_list = []
apicall_df_list_tmp = []
apicall_df_list = []
opcode_df_list_tmp = []
opcode_df_list = []

count = 0

df_opcodes = mpd.DataFrame()
df_permissions = mpd.DataFrame()
df_apicalls = mpd.DataFrame()

for file in files:
        count = count + 1
        
        print(chr(27) + "[2J")
        print(f"{count}/{total_files}")

        if is_permission_file(file.name):
             continue
            # df_tmp = mpd.read_csv(file.path)
            # df_tmp['file_name'] = file.name.split('-')[0]
            # permission_df_list_tmp.append(df_tmp)
        elif is_apicall_file(file.name):
            df_tmp = mpd.read_csv(file.path)
            # df_tmp['file_name'] = file.name.split('-')[0]
            apicall_df_list_tmp.append(df_tmp)
        elif is_opcode_file(file.name):
             continue
            # df_tmp = mpd.read_csv(file.path)
            # df_tmp['file_name'] = file.name.split('-')[0]
            # opcode_df_list_tmp.append(df_tmp)

        if len(apicall_df_list_tmp) == 1_000:
            print('Concatenando lote')
            apicall_df_list.append(mpd.concat(apicall_df_list_tmp, ignore_index=True))
            # permission_df_list.append(mpd.concat(permission_df_list_tmp, ignore_index=True))
            # opcode_df_list.append(mpd.concat(opcode_df_list_tmp, ignore_index=True))
            
            # count_group = 0
            apicall_df_list_tmp = []
            # permission_df_list_tmp = []
            # opcode_df_list_tmp = []



if len(apicall_df_list_tmp) > 0:
    print('Concatenando resto apicalls')
    apicall_df_list.append(mpd.concat(apicall_df_list_tmp, ignore_index=True))
    apicall_df_list_tmp = []

id = str(uuid.uuid4())
            
print('Concateo final apicalls')
df_apicalls = mpd.concat(apicall_df_list, ignore_index=True)
print('Salvando apicalls')
df_apicalls.to_csv(os.path.join(output_csv, f"APICALLS-{id}-parte5.csv"))
# Out:
# UserWarning: Distributing <class 'NoneType'> object. This may take some time.
# UserWarning: Distributing <class 'NoneType'> object. This may take some time.
# UserWarning: Distributing <class 'NoneType'> object. This may take some time.
# 1/15000
#
# 2/15000
#
# 3/15000
#
# 4/15000
#
# 5/15000
#
# 6/15000
#
# 7/15000
#
# 8/15000
#
# 9/15000
#
# 10/15000
#
# 11/15000
#
# 12/15000
#
# 13/15000
#
# 14/15000
#
# 15/15000
#
# 16/15000
#
# 17/15000
#
# 18/15000
#
# 19/15000
#
# 20/15000
#
# 21/15000
#
# 22/15000
#
# 23/15000
#
# 24/15000
#
# 25/15000
#
# 26/15000
#
# 27/15000
#
# 28/15000
#
# 29/15000
#
# 30/15000
#
# 31/15000
#
# 32/15000
#
# 33/15000
#
# 34/15000
#
# 35/15000
#
# 36/15000
#
# 37/15000
#
# 38/15000
#
# 39/15000
#
# 40/15000
#
# 41/15000
#
# 42/15000
#
# 43/15000
#
# 44/15000
#
# 45/15000
#
# 46/15000
#
# 47/15000
#
# 48/15000
#
# 49/15000
#
# 50/15000
#
# 51/15000
#
# 52/15000
#
# 53/15000
#
# 54/15000
#
# 55/15000
#
# 56/15000
#
# 57/15000
#
# 58/15000
#
# 59/15000
#
# 60/15000
#
# 61/15000
#
# 62/15000
#
# 63/15000
#
# 64/15000
#
# 65/15000
#
# 66/15000
#
# 67/15000
#
# 68/15000
#
# 69/15000
#
# 70/15000
#
# 71/15000
#
# 72/15000
#
# 73/15000
#
# 74/15000
#
# 75/15000
#
# 76/15000
#
# 77/15000
#
# 78/15000
#
# 79/15000
#
# 80/15000
#
# 81/15000
#
# 82/15000
#
# 83/15000
#
# 84/15000
#
# 85/15000
#
# 86/15000
#
# 87/15000
#
# 88/15000
#
# 89/15000
#
# 90/15000
#
# 91/15000
#
# 92/15000
#
# 93/15000
#
# 94/15000
#
# 95/15000
#
# 96/15000
#
# 97/15000
#
# 98/15000
#
# 99/15000
#
# 100/15000
#
# 101/15000
#
# 102/15000
#
# 103/15000
#
# 104/15000
#
# 105/15000
#
# 106/15000
#
# 107/15000
#
# 108/15000
#
# 109/15000
#
# 110/15000
#
# 111/15000
#
# 112/15000
#
# 113/15000
#
# 114/15000
#
# 115/15000
#
# 116/15000
#
# 117/15000
#
# 118/15000
#
# 119/15000
#
# 120/15000
#
# 121/15000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 27
#      23     # df_tmp = mpd.read_csv(file.path)
#      24     # df_tmp['file_name'] = file.name.split('-')[0]
#      25     # permission_df_list_tmp.append(df_tmp)
#      26 elif is_apicall_file(file.name):
# ---> 27     df_tmp = mpd.read_csv(file.path)
#      28     # df_tmp['file_name'] = file.name.split('-')[0]
#      29     apicall_df_list_tmp.append(df_tmp)
#
# File ~/Documents/pibic/.venv/lib/python3.10/site-packages/modin/utils.py:484, in expanduser_path_arg.<locals>.decorator.<locals>.wrapped(*args, **kw)
#     482     elif isinstance(patharg, Path):
#     483         params.arguments[argname] = patharg.expanduser()
# --> 484     return func(*params.args, **params.kwargs)
#     485 return func(*args, **kw)
#
# File ~/Documents/pibic/.venv/lib/python3.10/site-packages/modin/logging/logger_decorator.py:129, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     114 """
#     115 Compute function with logging if Modin logging is enabled.
#     116
#    (...)
#     126 Any
#     127 """
#     128 if LogMode.get() == "disable":
# --> 129     return obj(*args, **kwargs)
#     131 logger = get_logger()
#     132 logger_level = getattr(logger, log_level)
#
# File ~/Documents/pibic/.venv/lib/python3.10/site-packages/modin/pandas/io.py:227, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     225 _, _, _, f_locals = inspect.getargvalues(inspect.currentframe())
#     226 kwargs = {k: v for k, v in f_locals.items() if k in _pd_read_csv_signature}
# --> 227 return _read(**kwargs)
#
# File ~/Documents/pibic/.venv/lib/python3.10/site-packages/modin/pandas/io.py:117, in _read(**kwargs)
#     114 from modin.core.execution.dispatching.factories.dispatcher import FactoryDispatcher
#     116 squeeze = kwargs.pop("squeeze", False)
# --> 117 pd_obj = FactoryDispatcher.read_csv(**kwargs)
#     118 # This happens when `read_csv` returns a TextFileReader object for iterating through
#     119 if isinstance(pd_obj, TextFileReader):
#
# File ~/Documents/pibic/.venv/lib/python3.10/site-packages/modin/core/execution/dispatching/factories/dispatcher.py:192, in FactoryDispatcher.read_csv(cls, **kwargs)
#     189 @classmethod
#     190 @_inherit_docstrings(factories.BaseFactory._read_csv)
#     191 def read_csv(cls, **kwargs):
# --> 192     return cls.get_factory()._read_csv(**kwargs)
#
# File ~/Documents/pibic/.venv/lib/python3.10/site-packages/modin/core/execution/dispatching/factories/factories.py:222, in BaseFactory._read_csv(cls, **kwargs)
#     214 @classmethod
#     215 @doc(
#     216     _doc_io_method_template,
#    (...)
#     220 )
#     221 def _read_csv(cls, **kwargs):
# --> 222     return cls.io_cls.read_csv(**kwargs)
#
# File ~/Documents/pibic/.venv/lib/python3.10/site-packages/modin/logging/logger_decorator.py:129, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     114 """
#     115 Compute function with logging if Modin logging is enabled.
#     116
#    (...)
#     126 Any
#     127 """
#     128 if LogMode.get() == "disable":
# --> 129     return obj(*args, **kwargs)
#     131 logger = get_logger()
#     132 logger_level = getattr(logger, log_level)
#
# File ~/Documents/pibic/.venv/lib/python3.10/site-packages/modin/core/io/file_dispatcher.py:164, in FileDispatcher.read(cls, *args, **kwargs)
#     162     return cls.single_worker_read(fname, *args, reason=str(err), **kwargs)
#     163 # TextFileReader can also be returned from `_read`.
# --> 164 if not AsyncReadMode.get() and hasattr(query_compiler, "dtypes"):
#     165     # at the moment it is not possible to use `wait_partitions` function;
#     166     # in a situation where the reading function is called in a row with the
#     167     # same parameters, `wait_partitions` considers that we have waited for
#     168     # the end of remote calculations, however, when trying to materialize the
#     169     # received data, it is clear that the calculations have not yet ended.
#     170     # for example, `test_io_exp.py::test_read_evaluated_dict` is failed because of that.
#     171     # see #5944 for details
#     172     _ = query_compiler.dtypes
#     173 return query_compiler
#
# File ~/Documents/pibic/.venv/lib/python3.10/site-packages/modin/core/storage_formats/pandas/query_compiler.py:321, in PandasQueryCompiler.dtypes(self)
#     319 @property
#     320 def dtypes(self):
# --> 321     return self._modin_frame.dtypes
#
# File ~/Documents/pibic/.venv/lib/python3.10/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:366, in PandasDataframe.dtypes(self)
#     357 """
#     358 Compute the data types if they are not cached.
#     359
#    (...)
#     363     A pandas Series containing the data types for this dataframe.
#     364 """
#     365 if self.has_dtypes_cache:
# --> 366     dtypes = self._dtypes.get()
#     367 else:
#     368     dtypes = self._compute_dtypes()
#
# File ~/Documents/pibic/.venv/lib/python3.10/site-packages/modin/core/dataframe/pandas/metadata/dtypes.py:826, in ModinDtypes.get(self)
#     824 if not self.is_materialized:
#     825     if callable(self._value):
# --> 826         self._value = self._value()
#     827         if self._value is None:
#     828             self._value = pandas.Series([])
#
# File ~/Documents/pibic/.venv/lib/python3.10/site-packages/modin/core/io/text/text_file_dispatcher.py:941, in TextFileDispatcher._get_new_qc.<locals>.<lambda>()
#     899 """
#     900 Get new query compiler from data received from workers.
#     901
#    (...)
#     929     New query compiler, created from `new_frame`.
#     930 """
#     931 partition_ids = cls.build_partition(
#     932     partition_ids, [None] * len(index_ids), column_widths
#     933 )
#     935 new_frame = cls.frame_cls(
#     936     partition_ids,
#     937     lambda: cls._define_index(index_ids, index_name),
#     938     column_names,
#     939     None,
#     940     column_widths,
# --> 941     dtypes=lambda: cls.get_dtypes(dtypes_ids, column_names),
#     942 )
#     943 new_query_compiler = cls.query_compiler_cls(new_frame)
#     944 skipfooter = kwargs.get("skipfooter", None)
#
# File ~/Documents/pibic/.venv/lib/python3.10/site-packages/modin/logging/logger_decorator.py:129, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     114 """
#     115 Compute function with logging if Modin logging is enabled.
#     116
#    (...)
#     126 Any
#     127 """
#     128 if LogMode.get() == "disable":
# --> 129     return obj(*args, **kwargs)
#     131 logger = get_logger()
#     132 logger_level = getattr(logger, log_level)
#
# File ~/Documents/pibic/.venv/lib/python3.10/site-packages/modin/core/storage_formats/pandas/parsers.py:249, in PandasParser.get_dtypes(cls, dtypes_ids, columns)
#     246     return None
#     247 # each element in `partitions_dtypes` is a Series, where column names are
#     248 # used as index and types of columns for different partitions are used as values
# --> 249 partitions_dtypes = cls.materialize(dtypes_ids)
#     250 if all([len(dtype) == 0 for dtype in partitions_dtypes]):
#     251     return None
#
# File ~/Documents/pibic/.venv/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py:92, in RayWrapper.materialize(cls, obj_id)
#      77 @classmethod
#      78 def materialize(cls, obj_id):
#      79     """
#      80     Get the value of object from the Plasma store.
#      81
#    (...)
#      90         Whatever was identified by `obj_id`.
#      91     """
# ---> 92     return ray.get(obj_id)
#
# File ~/Documents/pibic/.venv/lib/python3.10/site-packages/ray/_private/auto_init_hook.py:21, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      18 @wraps(fn)
#      19 def auto_init_wrapper(*args, **kwargs):
#      20     auto_init_ray()
# ---> 21     return fn(*args, **kwargs)
#
# File ~/Documents/pibic/.venv/lib/python3.10/site-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File ~/Documents/pibic/.venv/lib/python3.10/site-packages/ray/_private/worker.py:2667, in get(object_refs, timeout)
#    2661     raise ValueError(
#    2662         f"Invalid type of object refs, {type(object_refs)}, is given. "
#    2663         "'object_refs' must either be an ObjectRef or a list of ObjectRefs. "
#    2664     )
#    2666 # TODO(ujvl): Consider how to allow user to retrieve the ready objects.
# -> 2667 values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#    2668 for i, value in enumerate(values):
#    2669     if isinstance(value, RayError):
#
# File ~/Documents/pibic/.venv/lib/python3.10/site-packages/ray/_private/worker.py:843, in Worker.get_objects(self, object_refs, timeout)
#     837         raise TypeError(
#     838             f"Attempting to call `get` on the value {object_ref}, "
#     839             "which is not an ray.ObjectRef."
#     840         )
#     842 timeout_ms = int(timeout * 1000) if timeout is not None else -1
# --> 843 data_metadata_pairs = self.core_worker.get_objects(
#     844     object_refs,
#     845     self.current_task_id,
#     846     timeout_ms,
#     847 )
#     848 debugger_breakpoint = b""
#     849 for data, metadata in data_metadata_pairs:
#
# KeyboardInterrupt:

# %%
teste = mpd.read_csv("csv/APICALLS-15119b04-07ae-44f5-b55d-755915b19a90-parte5.csv")
# Out:
# UserWarning: `read_*` implementation has mismatches with pandas:
# Data types of partitions are different! Please refer to the troubleshooting section of the Modin documentation to fix this issue.

# %%
teste.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  android.widget.TextView.setMaxEms  \
# 0             0           0                                1.0
# 1             1           0                                1.0
# 2             2           0                                NaN
# 3             3           0                                NaN
# 4             4           0                                NaN
#
#    android.view.View.getWindowVisibleDisplayFrame  \
# 0                                             7.0
# 1                                             4.0
# 2                                             2.0
# 3                                             5.0
# 4                                             4.0
#
#    java.util.Collections.synchronizedList  android.content.SharedPreferences  \
# 0                                    13.0                              594.0
# 1                                     4.0                              231.0
# 2                                     1.0                              300.0
# 3                                    22.0                              257.0
# 4                                     4.0                              218.0
#
#    android.widget.ImageButton.setElevation  java.lang.Runnable  \
# 0                                      1.0               166.0
# 1                                      NaN                76.0
# 2                                      NaN                75.0
# 3                                      NaN               137.0
# 4                                      2.0                58.0
#
#    java.security.spec.ECPoint  android.widget.EditText.setLineSpacing  ...  \
# 0                        18.0                                     1.0  ...
# 1                        11.0                                     NaN  ...
# 2                         NaN                                     NaN  ...
# 3                        11.0                                     NaN  ...
# 4                        16.0                                     NaN  ...
#
#    android.view.inputmethod.BaseInputConnection.performPrivateCommand  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    android.widget.EditText.getLocalVisibleRect  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    android.widget.EditText.getAnimation  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    android.view.inputmethod.BaseInputConnection.reportFullscreenMode  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    android.view.inputmethod.BaseInputConnection.getSelectedText  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    android.view.inputmethod.BaseInputConnection.requestCursorUpdates  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    android.view.inputmethod.BaseInputConnection.getExtractedText  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    android.view.ViewGroup.onKeyMultiple  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    android.view.ViewGroup.getHorizontalScrollbarHeight  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    android.view.ViewGroup.getHorizontalScrollbarThumbDrawable
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 43838 columns]
